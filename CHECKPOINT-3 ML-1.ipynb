# %% [markdown]
# <a href="https://colab.research.google.com/github/Shekhar1259/woc5.0-ml-weather-prediction-case-study--SHEKHAR-/blob/main/CHECKPOINT-3%20ML-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("influencer.csv", encoding='cp1252')
df
# Out:
#                                             Video Link Video Views  \
# 0          https://www.youtube.com/watch?v=_0fUOJ55gis     146,059
# 1          https://www.youtube.com/watch?v=_70MSLPRfZI     231,969
# 2    https://www.youtube.com/watch?v=_8gfCdt3H00&t=87s         878
# 3          https://www.youtube.com/watch?v=_CkFNJgKsFs       9,965
# 4          https://www.youtube.com/watch?v=_GFkHA5EZdE  39,780,561
# ..                                                 ...         ...
# 900        https://www.youtube.com/watch?v=GS18WawA-t0       6,892
# 901        https://www.youtube.com/watch?v=_tc_APkjH2Q      16,554
# 902        https://www.youtube.com/watch?v=Xfj4osSYfhU      32,798
# 903        https://www.youtube.com/watch?v=mGEHqwVz0eI       1,503
# 904        https://www.youtube.com/watch?v=UGATpt0I4vA     429,966
#
#                                            Video Title  \
# 0      Samse - Didupe Off-road Royal Enfield Himalayan
# ...

# %%
#df.isnull()

# %%
print(df.isnull().sum())
# Out:
# Video Link                                 0
# Video Views                                0
# Video Title                                0
# Channel URL                                0
# Creator Name                              11
# Creator Gender                           314
# Total Channel Subcribers                   0
# Total Chanel Views                         0
# Duration of Video                          0
# Duration in Seconds                        0
# Date of Video Upload                       0
# No of Likes                                1
# Language of the Video                     21
# Subtitle                                   1
# Video Description                          0
# Hashtags                                   0
# No of Comments                             0
# Date of the Last Comment                  24
# Maximum Quality of the Video               0
# No of Videos the Channel                   0
# No of Playlist                             9
# ...

# %%
df1=df.dropna()
df1
# Out:
#                                       Video Link Video Views  \
# 0    https://www.youtube.com/watch?v=_0fUOJ55gis     146,059
# 1    https://www.youtube.com/watch?v=_70MSLPRfZI     231,969
# 5    https://www.youtube.com/watch?v=_HwPGXsklyY     257,334
# 10   https://www.youtube.com/watch?v=0BBROgyHlFE   5,599,742
# 11   https://www.youtube.com/watch?v=0HheRYQ9ass      25,052
# ..                                           ...         ...
# 892  https://www.youtube.com/watch?v=3RMKX4Zzw68      75,789
# 893  https://www.youtube.com/watch?v=kqQTNKotVYk       1,640
# 894  https://www.youtube.com/watch?v=DQFbTVntxxg     491,854
# 895  https://www.youtube.com/watch?v=PGgtx0E-Jws     268,142
# 896  https://www.youtube.com/watch?v=tL-zKAkfFaw   1,378,946
#
#                                            Video Title  \
# 0      Samse - Didupe Off-road Royal Enfield Himalayan
# 1                             Bhoom Baddhal Web Series
# 5                       HERO - Baananchige Oduva Baara
# ...

# %%
df2=df1.drop(["Creator Gender","Date of the Last Comment","Intern Who Collected the Data","Date of Video Upload","Subtitle","Hashtags","Maximum Quality of the Video","Premiered or Not","Language of the Video","Duration of Video","Duration in Seconds"], axis=1)
df2
# Out:
#                                       Video Link Video Views  \
# 0    https://www.youtube.com/watch?v=_0fUOJ55gis     146,059
# 1    https://www.youtube.com/watch?v=_70MSLPRfZI     231,969
# 5    https://www.youtube.com/watch?v=_HwPGXsklyY     257,334
# 10   https://www.youtube.com/watch?v=0BBROgyHlFE   5,599,742
# 11   https://www.youtube.com/watch?v=0HheRYQ9ass      25,052
# ..                                           ...         ...
# 892  https://www.youtube.com/watch?v=3RMKX4Zzw68      75,789
# 893  https://www.youtube.com/watch?v=kqQTNKotVYk       1,640
# 894  https://www.youtube.com/watch?v=DQFbTVntxxg     491,854
# 895  https://www.youtube.com/watch?v=PGgtx0E-Jws     268,142
# 896  https://www.youtube.com/watch?v=tL-zKAkfFaw   1,378,946
#
#                                            Video Title  \
# 0      Samse - Didupe Off-road Royal Enfield Himalayan
# 1                             Bhoom Baddhal Web Series
# 5                       HERO - Baananchige Oduva Baara
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
cols = ['Video Link', 'Video Title', 'Channel URL', 'Creator Name','Video Description']
df2[cols] = df2[cols].apply(LabelEncoder().fit_transform)
df2
# Out:
#      Video Link Video Views  Video Title  Channel URL  Creator Name  \
# 0           141     146,059          409          348           404
# 1           142     231,969           91          130            84
# 5           143     257,334          204          233           298
# 10            4   5,599,742          387          169           180
# 11            5      25,052          451           68           316
# ..          ...         ...          ...          ...           ...
# 892          19      75,789          488          392           275
# 893         188       1,640          350          392           275
# 894          61     491,854          486           99            32
# 895         100     268,142          359           99            32
# 896         226   1,378,946          162           99            32
#
#     Total Channel Subcribers Total Chanel Views  No of Likes  \
# 0                      40200            7964284       6700.0
# ...
